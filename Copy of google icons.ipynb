# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from bs4 import BeautifulSoup
import requests,bs4

# %%
import numpy as np
import pandas as pd
import urllib.request as requests

# %%
url = 'https://about.google/intl/en_us/products/?tip=conversions'

# %%
response = requests.urlopen(url)
soup = BeautifulSoup(response, 'html.parser')

# %% [markdown]
# ## Extracting user icons from google products

# %%
iconTable = soup.find('ul',{'class':"product-icon-list"})

# %%
icons = iconTable.find_all('li')

# %% [markdown]
# ## Extracting google Business icons

# %%
iconTable1 = soup.find('ul',{'class':"product-icon-list"},id='zippy-2') # business icons

# %%
icons2 = iconTable.find_all('li')

# %% [markdown]
# ## Im saving extracted user icons in one folder
#
# ---

# %%
folder = r'C:\Users\MANIKANTA\Desktop\New folder (3)' + '\\'

# %%
folder = r'C:\Users\MANIKANTA\Desktop\New folder(3)' + '\\'
for icon in icons:
    requests.urlretrieve(icon.img['data-lazy-src'],folder + icon.img['alt'] +'.png')

# %% [markdown]
# ## Im saving Business icons in one folder

# %%
folder2 = r'C:\Users\MANIKANTA\Desktop\New folder (2)' + '\\'

# %%
folder = r'C:\Users\MANIKANTA\Desktop\New folder(2)' + '\\'
for icon in icons:
    requests.urlretrieve(icon.img['data-lazy-src'],folder + icon.img['alt'] +'.png')
